# %%
import pandas as pd
import numpy as np                     # For mathematical calculations
import seaborn as sns                  # For data visualization
import matplotlib.pyplot as plt        # For plotting graphs
# %matplotlib inline
import warnings   # To ignore any warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
train_original= train.copy()

# %%
train.corr(numeric_only=True)
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000  -0.172067   0.010507         -0.022753
# Attrition                -0.172067   1.000000  -0.051992          0.078074
# DailyRate                 0.010507  -0.051992   1.000000          0.027120
# DistanceFromHome         -0.022753   0.078074   0.027120          1.000000
# Education                 0.180723  -0.032631  -0.039805          0.006185
# EmployeeCount                  NaN        NaN        NaN               NaN
# EmployeeNumber            0.013321   0.033647  -0.055462          0.000823
# EnvironmentSatisfaction   0.029247  -0.132848   0.023005         -0.020197
# HourlyRate                0.005901  -0.017524   0.038572          0.048494
# JobInvolvement            0.044010  -0.150196   0.058871          0.051250
# JobLevel                  0.506484  -0.169201   0.003042         -0.024838
# ...

# %%
train.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1058.000000  1058.000000  1058.000000       1058.000000  1058.000000
# mean     37.055766     0.169187   809.542533          8.978261     2.879017
# std       9.410421     0.375094   408.478049          8.040608     1.031442
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.250000          2.000000     2.000000
# 50%      36.000000     0.000000   817.500000          7.000000     3.000000
# 75%      43.000000     0.000000  1168.500000         13.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1058.0     1058.000000              1058.000000  1058.000000
# mean             1.0      731.753308                 2.712665    65.643667
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1058 entries, 0 to 1057
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1058 non-null   int64
#  1   Attrition                 1058 non-null   int64
#  2   BusinessTravel            1058 non-null   object
#  3   DailyRate                 1058 non-null   int64
#  4   Department                1058 non-null   object
#  5   DistanceFromHome          1058 non-null   int64
#  6   Education                 1058 non-null   int64
#  7   EducationField            1058 non-null   object
#  8   EmployeeCount             1058 non-null   int64
#  9   EmployeeNumber            1058 non-null   int64
#  10  EnvironmentSatisfaction   1058 non-null   int64
#  11  Gender                    1058 non-null   object
#  12  HourlyRate                1058 non-null   int64
#  13  JobInvolvement            1058 non-null   int64
# ...

# %%
train.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
train.select_dtypes(np.number).sample(5)    ###  Random Sample of dataset with only Numerical Feature
# Out:
#      Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 329   47          0       1482                 5          5              1
# 721   50          0        939                24          3              1
# 328   33          0        508                10          3              1
# 70    59          0       1225                 1          1              1
# 987   51          0        541                 2          3              1
#
#      EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  ...  \
# 329             447                        4          42               3  ...
# 721            1005                        4          95               3  ...
# 328             446                        2          46               2  ...
# 70               91                        1          57               2  ...
# 987            1391                        2          52               3  ...
#
# ...

# %%
train.select_dtypes(include='O').sample(5)         ###  Random Sample of dataset with only categorical Feature
# Out:
#         BusinessTravel              Department   EducationField  Gender  \
# 101      Travel_Rarely  Research & Development    Life Sciences    Male
# 648  Travel_Frequently                   Sales          Medical  Female
# 826      Travel_Rarely         Human Resources  Human Resources    Male
# 375      Travel_Rarely  Research & Development            Other    Male
# 391      Travel_Rarely  Research & Development          Medical  Female
#
#                        JobRole MaritalStatus Over18 OverTime
# 101         Research Scientist        Single      Y       No
# 648       Sales Representative       Married      Y       No
# 826            Human Resources       Married      Y       No
# 375  Healthcare Representative        Single      Y       No
# 391      Laboratory Technician       Married      Y       No

# %%
print("Duplicates in Dataset: ",train.duplicated().sum())   ### Checking if There's Any Duplicate Records.
# Out:
# Duplicates in Dataset:  0

# %% [markdown]
# ## ***Dropping Attritbutes which doesn't imply any meaningful insights in our analysis.***

# %%
cols = ["Over18", "EmployeeCount", "EmployeeNumber", "StandardHours"]
train.drop(columns=cols, inplace=True)

# %%
plt.figure(1)
plt.subplot(331)
train['BusinessTravel'].value_counts(normalize=True).plot.bar(figsize=(20,10), title= 'BusinessTravel')
plt.xticks(rotation=30)

plt.subplot(332)
train['Department'].value_counts(normalize=True).plot.bar(title= 'Department')
plt.xticks(rotation=20)

plt.subplot(333)
train['EducationField'].value_counts(normalize=True).plot.bar(title= 'EducationField')
plt.xticks(rotation=40)

plt.subplot(334)
train['Gender'].value_counts(normalize=True).plot.bar(title= 'Gender')
plt.xticks(rotation=0)

plt.subplot(335)
train['JobRole'].value_counts(normalize=True).plot.bar(title= 'JobRole')
plt.xticks(rotation=30)

plt.subplot(336)
train['MaritalStatus'].value_counts(normalize=True).plot.bar(title= 'MaritalStatus')
plt.xticks(rotation=0)

plt.subplot(337)
train['OverTime'].value_counts(normalize=True).plot.bar(title= 'OverTime')
plt.xticks(rotation=0)

plt.subplots_adjust(hspace=1,wspace=1)

plt.show()

# %% [markdown]
# # **1. Visualizing the Employee Attrition Rate**

# %%
# plt.figure(1)


plt.subplot(122)
train['Attrition'].value_counts(normalize=True).plot.bar(title= 'Attrition')
plt.xticks(rotation=0)

plt.subplot(121)
train['Attrition'].value_counts(normalize=True).plot.pie(title= 'Attrition Rate', autopct="%.1f%%")
plt.show()

# %% [markdown]
# # **2.  Analyzing Employee Attrition by Gender .**

# %%
plt.figure(1)

plt.subplot(121)
plt.pie(x=train['Gender'].value_counts(),labels=train['Gender'].value_counts().index, autopct="%.1f%%")
plt.title('Distribution by Gender')


plt.subplot(122)
sns.barplot(x='Gender', y='Attrition', data=train,palette='Set2')
plt.title('Attrition Rate by Gender')

plt.subplots_adjust(hspace=1,wspace=1)

# %% [markdown]
# # **3. Analyzing Employee Attrition by Marital Status .**

# %%
plt.figure(1)

plt.subplot(121)
plt.pie(x=train['MaritalStatus'].value_counts(),labels=train['MaritalStatus'].value_counts().index, autopct="%.1f%%")
plt.title('Distribution by Marital Status');

plt.subplot(122)
sns.barplot(x='MaritalStatus',y = 'Attrition', data=train ,palette='Set2')
plt.title('Attrition Rate by Marital Status')

plt.subplots_adjust(hspace=0.5,wspace=0.5)

# %% [markdown]
# # **4 . Analyzing Employee Attrition by Business Travel.**

# %%
plt.figure(1)

plt.subplot(121)
plt.pie(x=train['BusinessTravel'].value_counts(),labels=train['BusinessTravel'].value_counts().index, autopct="%.1f%%");
plt.title('Distribution by Business Travel')

plt.subplot(122)
sns.barplot(x='BusinessTravel', y='Attrition', data=train ,palette='Set2')
plt.xticks(rotation=70)
plt.title('Attrition Rate by Business Travel')

plt.subplots_adjust(hspace=1,wspace=1)

# %% [markdown]
# # **5.  Analyzing Employee Attrition by Department**

# %%
plt.figure(1)


plt.subplot(121)
plt.pie(x=train['Department'].value_counts(),labels=train['Department'].value_counts().index, autopct="%.1f%%")
plt.title('Distribution by Department')

plt.subplot(122)
sns.barplot(x='Department', y='Attrition', data=train , palette='Set2')
plt.xticks(rotation=50)
plt.title('Attrition Rate by Department')
plt.subplots_adjust(hspace=1,wspace=1)

# %% [markdown]
# # **6. Analyzing Employee Attrition by Education.**

# %%
plt.figure(1)

plt.subplot(121)
plt.pie(x=train['Education'].value_counts(),labels=train['Education'].value_counts().index, autopct="%.1f%%")
plt.title('Distribution by Education')


plt.subplot(122)
sns.barplot(x='Education', y='Attrition', data=train , palette='Set2')
plt.title('Attrition Rate by Education');
plt.subplots_adjust(hspace=0.5,wspace=0.5)

# %% [markdown]
# # **7. Employee Distribution by Age .**

# %%
plt.figure(figsize=(14, 6))
plt.subplot(121)
sns.histplot(x='Age', hue='Attrition', data=train , kde=True , palette='Set2')
plt.title('Distribution by Age')

plt.subplot(122)
sns.boxplot(x='Attrition', y='Age', data=train, palette='Set2')
plt.title('Distribution by Age & Attrition');

# %% [markdown]
# # **8. Analyzing Employee Attrition by Education Field.**

# %%
plt.figure(figsize=(13.5, 8))
plt.subplot(121)
v1 = train['EducationField'].value_counts()
sns.barplot(x=v1.index, y=v1.values, order=v1.index, palette='Set2')
plt.xticks(rotation=70)
plt.title('Employee by Education Field')

plt.subplot(122)
sns.countplot(x='EducationField', hue='Attrition', data=train , palette='Set2')
plt.xticks(rotation=70)
plt.title('Employee Attrition by Education Field');

# %% [markdown]
# # **9. Analyzing Employee Attrition by Environment Satisfaction.**

# %%
# plt.figure(figsize=(12,5))
# plt.subplot(121)
# v1 = train['EnvironmentSatisfaction'].value_counts()
# sns.barplot(x=v1.index, y=v1.values, order=v1.index, palette='Set2');

plt.subplot(121)
plt.pie(x=train['EnvironmentSatisfaction'].value_counts(),labels=train['EnvironmentSatisfaction'].value_counts().index, autopct="%.1f%%")
plt.title('Distribution by EnvironmentSatisfaction ')

plt.subplot(122)
sns.countplot(x='EnvironmentSatisfaction', hue='Attrition', data=train , palette='Set2')
plt.title('Attrition Rate by EnvironmentSatisfaction')
plt.subplots_adjust(hspace=0.5,wspace=0.5);

# %%
plt.subplot(121)
env_sat_map = {1:'Very Low',2:'Low',3:'Medium',4:'High'}
plt.pie(x=train['EnvironmentSatisfaction'].value_counts().sort_index(),labels=env_sat_map.values(), autopct="%.1d%%");

plt.subplot(122)
sns.countplot(x='EnvironmentSatisfaction', hue='Attrition', data=train , palette='Set2');

plt.subplots_adjust(hspace=1,wspace=1)

# %% [markdown]
# # **10. Analyzing Employee Attrition by Job Satisfaction**

# %%
plt.subplot(121)
plt.pie(x=train['JobSatisfaction'].value_counts(),labels=train['JobSatisfaction'].value_counts().index, autopct="%.1f%%");
plt.title('Distribution by JobSatisfaction ')

plt.subplot(122)
sns.countplot(x='JobSatisfaction', hue='Attrition', data=train , palette='Set2')
plt.title('Attrition Rate by JobSatisfaction');

# %% [markdown]
# # 11.  Analyzing Employee Attrition by Relationship Satisfaction.

# %%
plt.subplot(121)
plt.pie(x=train['RelationshipSatisfaction'].value_counts(),labels=train['RelationshipSatisfaction'].value_counts().index, autopct="%.1f%%");
plt.title('Distribution by RelationshipSatisfaction ')

plt.subplot(122)
sns.countplot(x='RelationshipSatisfaction', hue='Attrition', data=train , palette='Set2')
plt.title('Distribution by RelationshipSatisfaction ')
plt.subplots_adjust(hspace=0.5,wspace=0.5);

# %% [markdown]
# # 12.  Analyzing Employee Attrition by Work Life Balance.

# %%
plt.subplot(121)
plt.pie(x=train['WorkLifeBalance'].value_counts(),labels=train['WorkLifeBalance'].value_counts().index, autopct="%.1f%%");
plt.title('Distribution by WorkLifeBalance ')

plt.subplot(122)
sns.countplot(x='WorkLifeBalance', hue='Attrition', data=train , palette='Set2')
plt.title('Attrition Rate by WorkLifeBalance ')
plt.subplots_adjust(wspace=0.5,hspace=0.5);

# %% [markdown]
# # 13.  Analyzing Employee Attrition by Performance Rating.

# %%
plt.subplot(121)
plt.pie(x=train['PerformanceRating'].value_counts(),labels=train['PerformanceRating'].value_counts().index, autopct="%.1f%%");
plt.title('Distribution by PerformanceRating ')

plt.subplot(122)
sns.countplot(x='PerformanceRating', hue='Attrition', data=train , palette='Set2')
plt.title('Attrition Rate by PerformanceRating ')
plt.subplots_adjust(wspace=0.5,hspace=0.5);

# %% [markdown]
# # 14.  Analyzing Employee Attrition by Over Time.

# %%
plt.subplot(121)
plt.pie(x=train['OverTime'].value_counts(),labels=train['OverTime'].value_counts().index, autopct="%.2f%%");
plt.title('Distribution by OverTime ')

plt.subplot(122)
sns.countplot(x='OverTime', hue = 'Attrition', data=train , palette='Set2')
plt.title('Attrition Rate by OverTime ')
plt.subplots_adjust(wspace=0.5,hspace=0.5);

# %% [markdown]
# # 15.  Analyzing Employee Attrition by Daily Rate.

# %%
plt.figure(figsize=(14, 6))
plt.subplot(121)
sns.histplot(x='DailyRate', hue='Attrition', data=train , kde=True , palette='Set2')
plt.title('Distribution by DailyRate ')

plt.subplot(122)
sns.boxplot(x='Attrition', y='DailyRate', data=train, palette='Set2')
plt.title('Distribution by DailyRate & Attrition');

# %% [markdown]
# # 16.  Analyzing Employee Attrition by Job Roles

# %%
plt.figure(figsize=(13.5, 8))
plt.subplot(121)
v1 = train['JobRole'].value_counts()
sns.barplot(x=v1.index, y=v1.values, order=v1.index, palette='Set2')
plt.xticks(rotation=70)
plt.title(' Employees By JobRole')

plt.subplot(122)
sns.countplot(x='JobRole', hue='Attrition', data=train , palette='Set2')
plt.xticks(rotation=70)
plt.title('Employee Attriton By JobRole ');

# %% [markdown]
# # 17.  Analyzing Employee Attrition by Job Level.

# %%
plt.figure(figsize=(13.5, 8))
plt.subplot(121)
v1 = train['JobLevel'].value_counts()
sns.barplot(x=v1.index, y=v1.values, order=v1.index, palette='Set2')
plt.title('Employee By JobLevel')

plt.subplot(122)
sns.countplot(x='JobLevel', hue='Attrition', data=train , palette='Set2')
plt.title('Employee Attrition By JobLevel ');

# %% [markdown]
# # 18.  Analyzing Employee Attrition by Monthly Income.

# %%
sns.boxplot(x = train['MonthlyIncome'])
# Out:
# <Axes: xlabel='MonthlyIncome'>

# %%
### OUTLIER TREATMENT
Q1 = train['MonthlyIncome'].quantile(0.25)
Q3 = train['MonthlyIncome'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR

train['MonthlyIncome'] = np.where(train['MonthlyIncome'] > upper, upper, np.where(train['MonthlyIncome'] < lower, lower, train['MonthlyIncome']))

# %%
plt.figure(figsize=(14, 6))
plt.subplot(121)
sns.histplot(x='MonthlyIncome', hue='Attrition', data=train , kde=True , palette='Set2')
plt.title('Distribution by MonthlyIncome ')

plt.subplot(122)
sns.boxplot(x='Attrition', y='MonthlyIncome', data=train, palette='Set2')
plt.title('Distribution by MonthlyIncome & Attrition');

# %% [markdown]
# # 19.  Analyzing Employee Attrition by Monthly Rate.

# %%
plt.figure(figsize=(14, 6))
plt.subplot(121)
sns.histplot(x='MonthlyRate', hue='Attrition', data=train , kde=True , palette='Set2')
plt.title('Distribution by MonthlyRate ')

plt.subplot(122)
sns.boxplot(x='Attrition', y='MonthlyRate', data=train, palette='Set2')
plt.title('Distribution by MonthlyRate & Attrition');

# %%
for col in train.columns:
    if train[col].dtype == object:
        print(f'{col}')
# Out:
# BusinessTravel
# Department
# EducationField
# Gender
# JobRole
# MaritalStatus
# OverTime

# %%
X = train.drop('Attrition', axis=1)
y = train['Attrition']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
train_enc = X.copy()
for col in X.columns:
  if X[col].dtype == 'object':
    lbd = LabelEncoder()
    train_enc[col] = lbd.fit_transform(X[col].values)

# %%
X.shape  , train_enc.shape
# Out:
# ((1058, 30), (1058, 30))

# %% [markdown]
# # Support Vector Algorithm

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
# dividing our data
X_train, X_test, y_train, y_test = train_test_split(train_enc,y)

# %%
svc = SVC() # No hyperparameter given means it will use default values .
svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
# %%time
svc.score(X_train,y_train) , svc.score(X_test, y_test) # training dataset
# Out:
# CPU times: total: 125 ms
# Wall time: 116 ms
# (0.8335435056746532, 0.8226415094339623)

# %% [markdown]
# # Using Naive Bayes Algorithm

# %%
from sklearn.naive_bayes import GaussianNB

# %%
# %%time

nb = GaussianNB()
nb.fit(X_train,y_train)
nb.score(X_train, y_train),nb.score(X_test, y_test)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 18.9 ms
# (0.7755359394703657, 0.7471698113207547)

# %% [markdown]
# # Using Logistic Regression Algorithm

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
y_pred = model.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[218   0]
#  [ 43   4]]

# %%
model.score(X_test, y_test) , model .score(X_train, y_train)
# Out:
# (0.8377358490566038, 0.8360655737704918)

# %% [markdown]
# # Using Decision Tree Classifier Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(criterion='gini', max_depth=5)

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
# %%time
dt.score(X_train, y_train) , dt.score(X_test, y_test)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 13 ms
# (0.905422446406053, 0.8226415094339623)

# %% [markdown]
# # Ensembling (Voting Classifier)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, VotingClassifier

# %%
clf1 = LogisticRegression(random_state=1)
clf2 = RandomForestClassifier(n_estimators=50, random_state=1)
clf3 = GaussianNB()

# %%
eclf1 = VotingClassifier(estimators=[
        ('lr', clf1), ('rf', clf2), ('gnb', clf3)], voting='hard')
eclf1 = eclf1.fit(X_train, y_train)
print(eclf1.predict(train_enc))
# Out:
# [1 0 1 ... 0 1 1]

# %%
# %%time
eclf1.score(X_train,y_train), eclf1.score(X_test, y_test)
# Out:
# CPU times: total: 188 ms
# Wall time: 89.8 ms
# (0.9495586380832283, 0.8566037735849057)

# %% [markdown]
# # Conclusion

# %%
# After conducting a thorough analysis and comparing various regression models,
# the logistic regression algorithm has demonstrated the highest performance score.
# This indicates that the logistic regression model is the most suitable for our dataset and problem at hand.
